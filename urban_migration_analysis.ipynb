# %% [markdown]
# **DATA PREPROCESSING**

# %% [markdown]
# ### Analyzing and cleaning data

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio

# %%
# Use pd.read_excel to read the Excel file
df = pd.read_excel("/content/province_cleaned_final.xlsx")

# %%
df.drop("Unnamed: 0", inplace=True, axis=1)

# %%
df.head()
# Out:
#    Year  Islamabad  Punjab  Sindh    KPK  Balochistan  Azad Kashmir  \
# 0  1981         23   75506  22800  38485         1755         12094
# 1  1982         65   71401  22571  29697         1461          8945
# 2  1983        245   67731  18997  18035          971          9822
# 3  1984         82   48029  17202  16147         1067          8321
# 4  1985        215   40643  12259  17725          724          5011
#
#    Northern Areas  Tribal Areas   Total
# 0               4          2414  153081
# 1               6          3389  137535
# 2               7          4223  120031
# 3               1          2691   93540
# 4              18          5738   82333

# %%
# df.drop(45,inplace=True,axis=0) ---dropped a null value
df.tail()
# Out:
#     Year  Islamabad  Punjab  Sindh     KPK  Balochistan  Azad Kashmir  \
# 40  2021       2285  157699  21501   76484         2473         10705
# 41  2022       6554  460302  59337  225272         8018         29512
# 42  2023      10359  489301  72382  210150         8369         33904
# 43  2024       8621  404345  60424  187103         5668         29591
# 44  2025       1378   59502   9112   32325          859          4676
#
#     Northern Areas  Tribal Areas   Total
# 40            1095         16038  288280
# 41            1180         42164  832339
# 42            1551         36609  862625
# 43            1692         29937  727381
# 44             291          5446  113589

# %% [markdown]
# Data is sorted chronologically.

# %%
df.columns
# Out:
# Index(['Year', 'Islamabad', 'Punjab', 'Sindh', 'KPK', 'Balochistan',
#        'Azad Kashmir', 'Northern Areas', 'Tribal Areas', 'Total'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            45 non-null     int64
#  1   Islamabad       45 non-null     int64
#  2   Punjab          45 non-null     int64
#  3   Sindh           45 non-null     int64
#  4   KPK             45 non-null     int64
#  5   Balochistan     45 non-null     int64
#  6   Azad Kashmir    45 non-null     int64
#  7   Northern Areas  45 non-null     int64
#  8   Tribal Areas    45 non-null     int64
#  9   Total           45 non-null     int64
# dtypes: int64(10)
# memory usage: 3.6 KB

# %%
df.describe()
# Out:
#               Year     Islamabad         Punjab          Sindh            KPK  \
# count    45.000000     45.000000      45.000000      45.000000      45.000000
# mean   2003.000000   2443.244444  157015.511111   27906.644444   77326.422222
# std      13.133926   3072.930302  139388.552206   25956.783800   66127.384538
# min    1981.000000     23.000000   28362.000000    6373.000000   14575.000000
# 25%    1992.000000    536.000000   59769.000000   10607.000000   27695.000000
# 50%    2003.000000    933.000000   81193.000000   15461.000000   42946.000000
# 75%    2014.000000   2471.000000  199692.000000   40171.000000  114633.000000
# max    2025.000000  10359.000000  489301.000000  116935.000000  225272.000000
#
#        Balochistan  Azad Kashmir  Northern Areas  Tribal Areas          Total
# count    45.000000     45.000000       45.000000     45.000000      45.000000
# mean   3167.155556  17797.333333      668.622222  14938.511111  301263.444444
# std    2392.587046  14823.350452      943.846465  12461.098050  260853.963265
# min     389.000000   3573.000000        1.000000   2414.000000   58002.000000
# 25%    1441.000000   7691.000000       19.000000   5655.000000  113781.000000
# 50%    2127.000000  10352.000000      256.000000   9030.000000  154529.000000
# 75%    4528.000000  30158.000000      780.000000  21831.000000  430314.000000
# max    9293.000000  64586.000000     3417.000000  45798.000000  946571.000000

# %%
df.dtypes
# Out:
# Year              int64
# Islamabad         int64
# Punjab            int64
# Sindh             int64
# KPK               int64
# Balochistan       int64
# Azad Kashmir      int64
# Northern Areas    int64
# Tribal Areas      int64
# Total             int64
# dtype: object

# %% [markdown]
# **Checking Null Rows.**

# %%
#Checking any null values in dataset
df.isnull().sum()
# Out:
# Year              0
# Islamabad         0
# Punjab            0
# Sindh             0
# KPK               0
# Balochistan       0
# Azad Kashmir      0
# Northern Areas    0
# Tribal Areas      0
# Total             0
# dtype: int64

# %%
#Size of dataset
df.shape
# Out:
# (45, 10)

# %% [markdown]
# Till here dataframe is already clean.

# %% [markdown]
# Data Cleaning and Data Analysis is complete at this stage.

# %% [markdown]
# ## **Data Visualization:**

# %%
# Remove 'Total' for regional comparisons
df_regions = df.drop(columns=['Total'])

# Melt data for easier plotting
df_melted = df_regions.melt(id_vars='Year', value_vars=['Islamabad', 'Punjab', 'Sindh', 'KPK', 'Balochistan',
                                                       'Azad Kashmir', 'Northern Areas', 'Tribal Areas'],
                            var_name='Region', value_name='Population')

# 1. Scatter Plot: Population values by year for each region
fig1 = px.scatter(df_melted, x='Year', y='Population', color='Region',
                  title='Population Trends by Region in Pakistan (1981–1985)',
                  labels={'Population': 'Population Count'},
                  template='plotly_dark')
fig1.update_layout(title_x=0.5)
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9fc9ad4c-9b53-4a90-b6fe-35f4775f436b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9fc9ad4c-9b53-4a90-b6fe-35f4775f436b")) {                    Plotly.newPlot(                        "9fc9ad4c-9b53-4a90-b6fe-35f4775f436b",                        [{"hovertemplate":"Region=Islamabad\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Islamabad","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Islamabad","orientation":"v","showlegend":true,"x":[1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[23,65,245,82,215,177,327,326,351,701,744,778,531,731,875,536,772,671,630,881,1094,425,933,959,992,876,1263,9050,1569,1168,1790,4190,7109,8943,9028,8472,4635,2471,4298,1823,2285,6554,10359,8621,1378],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Punjab\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Punjab","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Punjab","orientation":"v","showlegend":true,"x":[1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[75506,71401,67731,48029,40643,28362,33132,41330,46930,60041,73949,100095,81193,52060,59769,64442,74364,52534,35514,49273,60197,72237,115471,96087,76476,99305,153037,197234,199692,189379,226917,337684,326012,383533,478646,446566,261849,185902,312960,119067,157699,460302,489301,404345,59502],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Sindh\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sindh","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Sindh","orientation":"v","showlegend":true,"x":[1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[22800,22571,18997,17202,12259,6445,7595,8713,10253,12465,13628,15461,13769,7672,10607,10417,10792,6431,6373,8329,9447,10826,12963,11914,11747,14831,20426,31727,30779,31814,40171,46607,55608,89703,116935,85326,53590,41551,57206,17093,21501,59337,72382,60424,9112],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=KPK\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"KPK","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"KPK","orientation":"v","showlegend":true,"x":[1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[38485,29697,18035,16147,17725,14575,15481,18933,22909,25612,37219,49147,36902,30102,27309,27695,40240,26563,24725,35461,42521,46815,59604,42946,35106,44789,76729,131404,114633,98222,130119,176349,150418,167424,220993,206929,107366,88361,186283,68382,76484,225272,210150,187103,32325],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Balochistan\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Balochistan","marker":{"color":"#FFA15A","symbol":"circle"} ...

# %%
import plotly.graph_objects as go

# Get unique years
years = df['Year'].unique()

# Create data and dropdown buttons
data = []
buttons = []

for i, year in enumerate(years):
    df_year = df[df['Year'] == year][['Islamabad', 'Punjab', 'Sindh', 'KPK', 'Balochistan',
                                      'Azad Kashmir', 'Northern Areas', 'Tribal Areas']].T
    df_year.columns = ['Population']
    df_year['Region'] = df_year.index

    # Create pie trace
    trace = go.Pie(labels=df_year['Region'],
                   values=df_year['Population'],
                   name=str(year),
                   visible=(i == 0))  # Show only the first year initially
    data.append(trace)

    # Create dropdown button
    buttons.append(dict(label=str(year),
                        method='update',
                        args=[{'visible': [j == i for j in range(len(years))]},
                              {'title': f'Regional Population Shares in Pakistan ({year})'}]))

# Create layout with dropdown centered above chart
layout = go.Layout(
    title='Regional Population Shares in Pakistan (1981)',
    template='plotly_dark',
    updatemenus=[dict(
        buttons=buttons,
        direction='down',
        showactive=True,
        x=0.5,           # Center horizontally
        xanchor='center',
        y=1.11,          # Above the chart
        yanchor='top'
    )]
)

fig = go.Figure(data=data, layout=layout)
fig.update_layout(title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7be4b798-6343-471a-b282-abc308b90aa9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7be4b798-6343-471a-b282-abc308b90aa9")) {                    Plotly.newPlot(                        "7be4b798-6343-471a-b282-abc308b90aa9",                        [{"labels":["Islamabad","Punjab","Sindh","KPK","Balochistan","Azad Kashmir","Northern Areas","Tribal Areas"],"name":"1981","values":[23,75506,22800,38485,1755,12094,4,2414],"visible":true,"type":"pie"},{"labels":["Islamabad","Punjab","Sindh","KPK","Balochistan","Azad Kashmir","Northern Areas","Tribal Areas"],"name":"1982","values":[65,71401,22571,29697,1461,8945,6,3389],"visible":false,"type":"pie"},{"labels":["Islamabad","Punjab","Sindh","KPK","Balochistan","Azad Kashmir","Northern Areas","Tribal Areas"],"name":"1983","values":[245,67731,18997,18035,971,9822,7,4223],"visible":false,"type":"pie"},{"labels":["Islamabad","Punjab","Sindh","KPK","Balochistan","Azad Kashmir","Northern Areas","Tribal Areas"],"name":"1984","values":[82,48029,17202,16147,1067,8321,1,2691],"visible":false,"type":"pie"},{"labels":["Islamabad","Punjab","Sindh","KPK","Balochistan","Azad Kashmir","Northern Areas","Tribal Areas"],"name":"1985","values":[215,40643,12259,17725,724,5011,18,5738],"visible":false,"type":"pie"},{"labels":["Islamabad","Punjab","Sindh","KPK","Balochistan","Azad Kashmir","Northern Areas","Tribal Areas"],"name":"1986","values":[177,28362,6445,14575,389,3573,19,4462],"visible":false,"type":"pie"},{"labels":["Islamabad","Punjab","Sindh","KPK","Balochistan","Azad Kashmir","Northern Areas","Tribal Areas"],"name":"1987","values":[327,33132,7595,15481,642,4873,6,4130],"visible":false,"type":"pie"},{"labels":["Islamabad","Punjab","Sindh","KPK","Balochistan","Azad Kashmir","Northern Areas","Tribal Areas"],"name":"1988","values":[326,41330,8713,18933,1153,5750,18,5322],"visible":false,"type":"pie"},{"labels":["Islamabad","Punjab","Sindh","KPK","Balochistan","Azad Kashmir","Northern Areas","Tribal Areas"],"name":"1989","values":[351,46930,10253,22909,1644,6005,5,7766],"visible":false,"type":"pie"},{"labels":["Islamabad","Punjab","Sindh","KPK","Balochistan","Azad Kashmir","Northern Areas","Tribal Areas"],"name":"1990","values":[701,60041,12465,25612,2127,6261,3,6571],"visible":false,"type":"pie"},{"labels":["Islamabad","Punjab","Sindh","KPK","Balochistan","Azad Kashmir","Northern Areas","Tribal Areas"],"name":"1991","values":[744,73949,13628,37219,945,8706,5,7622],"visible":false,"type":"pie"},{"labels":["Islamabad","Punjab","Sindh","KPK","Balochistan","Azad Kashmir","Northern Areas","Tribal Areas"],"name":"1992","values":[778,100095,15461,49147,1989,10352,17,13667],"visible":false,"type":"pie"},{"labels":["Islamabad","Punjab","Sindh","KPK","Balochistan","Azad Kashmir","Northern Areas","Tribal Areas"],"name":"1993","values":[531,81193,13769,36902,1441,8720,104,11869],"visible":false,"type":"pie"},{"labels":["Islamabad","Punjab","Sindh","KPK","Balochistan","Azad Kashmir","Northern Areas","Tribal Areas"],"name":"1994","values":[731,52060,7672,30102,1135,7733,159,11344],"visible":false,"type":"pie"},{"labels":["Islamabad","Punjab","Sindh","KPK","Balochistan","Azad Kashmir","Northern Areas","Tribal Areas"],"name":"1995","values":[875,59769,10607,27309,1367,9004,145,7972],"visible":false,"type":"pie"},{"labels":["Islamabad","Punjab","Sindh","KPK","Balochistan","Azad Kashmir","Northern Areas","Tribal Areas"],"name":"1996","values":[536,64442,10417,27695,1420,9280,184,5655],"visible":false,"type":"pie"},{"labels":["Islamabad","Punjab","Sindh","KPK","Balochistan","Azad Kashmir","Northern Areas","Tribal Areas"],"name":"1997","values":[772,74364,10792,40240,1673,11602,372,9214],"visible":false,"type":" ...

# %%
# 3. Normalized Stacked Bar Plot: Relative contribution to Total over time
df_normalized = df_regions.copy()
for col in ['Islamabad', 'Punjab', 'Sindh', 'KPK', 'Balochistan', 'Azad Kashmir', 'Northern Areas', 'Tribal Areas']:
    df_normalized[col] = df_normalized[col] / df['Total'] * 100
df_normalized_melted = df_normalized.melt(id_vars='Year', value_vars=['Islamabad', 'Punjab', 'Sindh', 'KPK',
                                                                     'Balochistan', 'Azad Kashmir', 'Northern Areas',
                                                                     'Tribal Areas'],
                                          var_name='Region', value_name='Percentage')
fig3 = px.bar(df_normalized_melted, x='Year', y='Percentage', color='Region', barmode='stack',
              title='Normalized Regional Contributions to Total Population (1981–2025)',
              labels={'Percentage': 'Percentage of Total Population (%)'},
              template='plotly_dark')
fig3.update_layout(title_x=0.5)
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3b34d137-5236-46f5-8f8c-55c82024ba7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b34d137-5236-46f5-8f8c-55c82024ba7a")) {                    Plotly.newPlot(                        "3b34d137-5236-46f5-8f8c-55c82024ba7a",                        [{"alignmentgroup":"True","hovertemplate":"Region=Islamabad\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage of Total Population (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Islamabad","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"
"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Region=KPK\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation Count (Log Scale)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"KPK","line":{"color":"#ab63fa"},"marker":{"symbol":"circle"},"mode":"lines","name":"KPK","orientation":"v","showlegend":true,"stackgroup":"1","x":[1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[38485,29697,18035,16147,17725,14575,15481,18933,22909,25612,37219,49147,36902,30102,27309,27695,40240,26563,24725,35461,42521,46815,59604,42946,35106,44789,76729,131404,114633,98222,130119,176349,150418,167424,220993,206929,107366,88361,186283,68382,76484,225272,210150,18 ...

# %%
# 5. Violin Plot: Distribution of population across regions
fig5 = px.violin(df_melted, x='Region', y='Population',
                 title='Population Distribution by Region in Pakistan (1981–2025)',
                 labels={'Population': 'Population Count'},
                 template='plotly_dark')
fig5.update_layout(title_x=0.5)
fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d391bfba-63a5-41ca-9655-673bc8411ce1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d391bfba-63a5-41ca-9655-673bc8411ce1")) {                    Plotly.newPlot(                        "d391bfba-63a5-41ca-9655-673bc8411ce1",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Region=%{x}\u003cbr\u003ePopulation Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","offsetgroup":"","orientation":"v","scalegroup":"True","showlegend":false,"x":["Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Ar ...

# %%
# Previous Plots (Updated with Proper Titles)
# 6. Line Plot: Trends over time
fig6 = px.line(df_melted, x='Year', y='Population', color='Region',
               title='Population Trends by Region in Pakistan (1981–2025)',
               labels={'Population': 'Population Count'},
               template='plotly_dark')
fig6.update_layout(title_x=0.5)
fig6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="754a77fe-8b13-4f31-853d-173d9fbaeeb8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("754a77fe-8b13-4f31-853d-173d9fbaeeb8")) {                    Plotly.newPlot(                        "754a77fe-8b13-4f31-853d-173d9fbaeeb8",                        [{"hovertemplate":"Region=Islamabad\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Islamabad","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Islamabad","orientation":"v","showlegend":true,"x":[1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[23,65,245,82,215,177,327,326,351,701,744,778,531,731,875,536,772,671,630,881,1094,425,933,959,992,876,1263,9050,1569,1168,1790,4190,7109,8943,9028,8472,4635,2471,4298,1823,2285,6554,10359,8621,1378],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Punjab\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Punjab","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Punjab","orientation":"v","showlegend":true,"x":[1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[75506,71401,67731,48029,40643,28362,33132,41330,46930,60041,73949,100095,81193,52060,59769,64442,74364,52534,35514,49273,60197,72237,115471,96087,76476,99305,153037,197234,199692,189379,226917,337684,326012,383533,478646,446566,261849,185902,312960,119067,157699,460302,489301,404345,59502],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Sindh\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sindh","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Sindh","orientation":"v","showlegend":true,"x":[1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[22800,22571,18997,17202,12259,6445,7595,8713,10253,12465,13628,15461,13769,7672,10607,10417,10792,6431,6373,8329,9447,10826,12963,11914,11747,14831,20426,31727,30779,31814,40171,46607,55608,89703,116935,85326,53590,41551,57206,17093,21501,59337,72382,60424,9112],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=KPK\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"KPK","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"KPK","orientation":"v","showlegend":true,"x":[1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[38485,29697,18035,16147,17725,14575,15481,18933,22909,25612,37219,49147,36902,30102,27309,27695,40240,26563,24725,35461,42521,46815,59604,42946,35106,44789,76729,131404,114633,98222,130119,176349,150418,167424,220993,206929,107366,88361,186283,68382,76484,225272,210150,187103,32325],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Balochistan\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation Count=%{y}\u003cextra\u003e\u003c\u002 ...

# %%
# 7. Stacked Area Plot: Regional contributions
fig7 = px.area(df_melted, x='Year', y='Population', color='Region',
               title='Stacked Area: Regional Population Contributions in Pakistan (1981–2025)',
               labels={'Population': 'Population Count'},
               template='plotly_dark')
fig7.update_layout(title_x=0.5)
fig7.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="504cb115-4a6b-460b-a2af-95e356d14327" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("504cb115-4a6b-460b-a2af-95e356d14327")) {                    Plotly.newPlot(                        "504cb115-4a6b-460b-a2af-95e356d14327",                        [{"fillpattern":{"shape":""},"hovertemplate":"Region=Islamabad\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Islamabad","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"Islamabad","orientation":"v","showlegend":true,"stackgroup":"1","x":[1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025],"xaxis":"x","y":
show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c7d7843b-9aaa-4d4f-9be5-541543f41b0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7d7843b-9aaa-4d4f-9be5-541543f41b0c")) {                    Plotly.newPlot(                        "c7d7843b-9aaa-4d4f-9be5-541543f41b0c",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003ePopulation Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Islamabad","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Punjab","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","Sindh","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","KPK","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Balochistan","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Azad Kashmir","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","Northern Areas","North ...

# %%
# 10. Heatmap: Values across regions and years
df_heatmap = df.set_index('Year')[['Islamabad', 'Punjab', 'Sindh', 'KPK', 'Balochistan',
                                   'Azad Kashmir', 'Northern Areas', 'Tribal Areas']]
fig10 = px.imshow(df_heatmap.T,
                  title='Heatmap of Population by Region and Year in Pakistan (1981–2025)',
                  labels={'color': 'Population Count'},
                  template='plotly_dark')
fig10.update_layout(title_x=0.5, xaxis_title='Year', yaxis_title='Region')
fig10.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8d21f5b0-e7ba-40dc-85dc-8f2d60947641" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d21f5b0-e7ba-40dc-85dc-8f2d60947641")) {                    Plotly.newPlot(                        "8d21f5b0-e7ba-40dc-85dc-8f2d60947641",                        [{"coloraxis":"coloraxis","name":"0","x":[1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025],"y":["Islamabad","Punjab","Sindh","KPK","Balochistan","Azad Kashmir","Northern Areas","Tribal Areas"],"z":[[23,65,245,82,215,177,327,326,351,701,744,778,531,731,875,536,772,671,630,881,1094,425,933,959,992,876,1263,9050,1569,1168,1790,4190,7109,8943,9028,8472,4635,2471,4298,1823,2285,6554,10359,8621,1378],[75506,71401,67731,48029,40643,28362,33132,41330,46930,60041,73949,100095,81193,52060,59769,64442,74364,52534,35514,49273,60197,72237,115471,96087,76476,99305,153037,197234,199692,189379,226917,337684,326012,383533,478646,446566,261849,185902,312960,119067,157699,460302,489301,404345,59502],[22800,22571,18997,17202,12259,6445,7595,8713,10253,12465,13628,15461,13769,7672,10607,10417,10792,6431,6373,8329,9447,10826,12963,11914,11747,14831,20426,31727,30779,31814,40171,46607,55608,89703,116935,85326,53590,41551,57206,17093,21501,59337,72382,60424,9112],[38485,29697,18035,16147,17725,14575,15481,18933,22909,25612,37219,49147,36902,30102,27309,27695,40240,26563,24725,35461,42521,46815,59604,42946,35106,44789,76729,131404,114633,98222,130119,176349,150418,167424,220993,206929,107366,88361,186283,68382,76484,225272,210150,187103,32325],[1755,1461,971,1067,724,389,642,1153,1644,2127,945,1989,1441,1135,1367,1420,1673,1444,1727,2544,1867,1584,2834,3194,3098,3392,3698,6809,4480,3130,5262,5122,9293,7258,7686,6378,4528,2930,5103,1871,2473,8018,8369,5668,859],[12094,8945,9822,8321,5011,3573,4873,5750,6005,6261,8706,10352,8720,7733,9004,9280,11602,6236,3750,6269,6421,8382,12097,11092,8958,11976,19516,31881,31329,22535,33133,38833,40038,52120,64586,43093,33318,33028,30158,7691,10705,29512,33904,29591,4676],[4,6,7,1,18,19,6,18,5,3,5,17,104,159,145,184,372,158,149,77,213,105,157,275,374,364,369,378,507,458,732,780,1190,2073,2899,2961,3417,2760,2554,256,1095,1180,1551,1692,291],[2414,3389,4223,2691,5738,4462,4130,5322,7766,6571,7622,13667,11869,11344,7972,5655,9214,6669,5225,4899,6169,7048,9980,7357,5384,7658,11995,21831,20539,16198,18769,29022,33046,41412,45798,39628,27583,25436,27314,9030,16038,42164,36609,29937,5446]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Year: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ePopulation Count: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[ ...

# %% [markdown]
# ##**Modelling**
#
# ####**Model Development**

# %%
df_mc = df[['Year', 'Total']].copy()
df_mc.set_index('Year', inplace=True)

# Calculate annual percentage change
df_mc['Pct_Change'] = df_mc['Total'].pct_change()
historical_mean = df_mc['Pct_Change'].mean()
historical_std = df_mc['Pct_Change'].std()

# Monte Carlo parameters
num_simulations = 1000
num_years = 5
last_known_year = df_mc.index[-1]
last_known_value = df_mc['Total'].iloc[-1]

simulated_data = []

# Generate simulations
for _ in range(num_simulations):
    values = [last_known_value]
    for _ in range(num_years):
        growth_rate = np.random.normal(historical_mean, historical_std)
        next_value = values[-1] * (1 + growth_rate)
        values.append(next_value)
    simulated_data.append(values[1:])  # Exclude the known value

simulated_data = np.array(simulated_data)

# Compute statistics
forecast_years = list(range(last_known_year + 1, last_known_year + 1 + num_years))
mean_forecast = simulated_data.mean(axis=0)
lower_bound = np.percentile(simulated_data, 2.5, axis=0)
upper_bound = np.percentile(simulated_data, 97.5, axis=0)

# Prepare dataframe for plotting
df_forecast = pd.DataFrame({
    'Year': forecast_years,
    'Mean Forecast': mean_forecast,
    'Lower Bound (95%)': lower_bound,
    'Upper Bound (95%)': upper_bound
})

# Plot
fig = px.line(df_forecast, x='Year', y='Mean Forecast', title='Monte Carlo Forecast: Pakistan Total Population (2026–2030)',
              labels={'value': 'Population Count', 'Year': 'Year'}, template='plotly_dark')
fig.add_scatter(x=forecast_years, y=lower_bound, mode='lines', name='Lower Bound (95%)',
                line=dict(dash='dot', color='gray'))
fig.add_scatter(x=forecast_years, y=upper_bound, mode='lines', name='Upper Bound (95%)',
                line=dict(dash='dot', color='gray'))

# Add historical actuals
df_actual = df_mc.reset_index()
fig.add_scatter(x=df_actual['Year'], y=df_actual['Total'], mode='lines+markers', name='Actual')

fig.update_layout(title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="61c32962-48ed-4b35-819d-bc15f520021d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61c32962-48ed-4b35-819d-bc15f520021d")) {                    Plotly.newPlot(                        "61c32962-48ed-4b35-819d-bc15f520021d",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eMean Forecast=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2026,2027,2028,2029,2030],"xaxis":"x","y":[122955.03824360126,133411.19039794008,143100.63827892195,153949.6211921457,167250.13711854312],"yaxis":"y","type":"scatter"},{"line":{"color":"gray","dash":"dot"},"mode":"lines","name":"Lower Bound (95%)","x":[2026,2027,2028,2029,2030],"y":[33382.958432657215,14253.614111800136,6914.815508817037,4473.894718196893,992.8933823771378],"type":"scatter"},{"line":{"color":"gray","dash":"dot"},"mode":"lines","name":"Upper Bound (95%)","x":[2026,2027,2028,2029,2030],"y":[217201.6361415335,293622.7813996722,395614.5762353256,495392.4127423926,620463.4444073446],"type":"scatter"},{"mode":"lines+markers","name":"Actual","x":[1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025],"y":[153081,137535,120031,93540,82333,58002,66186,81545,95863,113781,142818,191506,154529,110936,117048,119629,149029,100706,78093,107733,127929,147422,214039,173824,142135,183191,287033,430314,403528,362904,456893,638587,622714,752466,946571,839353,496286,382439,625876,225213,288280,832339,862625,727381,113589],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"hist ...
